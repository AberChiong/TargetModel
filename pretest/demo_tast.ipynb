# %%
import moleculekit.molecule as ht
import moleculekit.tools.voxeldescriptors as vd
import moleculekit.smallmol.smallmol as sm
from tqdm import *
from oddt import datasets
from moleculekit.tools.atomtyper import prepareProteinForAtomtyping
from moleculekit.tools.preparation import systemPrepare
from sklearn.model_selection import train_test_split
import numpy as np
import os
import h5py

# %%
# 设置路径
data_dir = ".\\data"
pdbbind_dir = os.path.join(data_dir, "refined-set-2016\\")
pdbbind_dataset = datasets.pdbbind(home=pdbbind_dir, default_set='refined', version=2016)

# %%
def get_pdb_complex_feature(pro_file, lig_file):
    """ 返回组合了protein和ligand的element feature体素化结果 """

    # 分别读取蛋白质分子的 .pdbqt 和小分子的 .mol2 文件
    pro_mol = ht.Molecule(pro_file)
    lig_mol = sm.SmallMol(lig_file)

    # 定义盒子大小和体素化中心（小分子的欧几里得中心）
    n = [24, 24, 24]
    center = list(sm.SmallMol.getCenter(lig_mol))

    # 体素化
    # 蛋白质准备
    _ = pro_mol.remove("element H")
    _ = pro_mol.filter('protein')
    try:
        pro_mol = prepareProteinForAtomtyping(pro_mol, verbose=False)
    except Exception as e:
        if 'ignore_ns_errors=True' in str(e):
            pro_mol = systemPrepare(pro_mol, ignore_ns_errors=True, verbose=False)
            pro_mol = prepareProteinForAtomtyping(pro_mol,protonate=False, verbose=False)
    
    # 蛋白质体素化过程
    pro_vox, pro_centers, pro_N = vd.getVoxelDescriptors(pro_mol, boxsize=n, center=center)
    p_features = pro_vox.reshape(pro_N[0], pro_N[1], pro_N[2], pro_vox.shape[1])
    # 小分子体素化过程
    lig_vox, lig_centers, lig_N = vd.getVoxelDescriptors(lig_mol, boxsize=n, center=center)
    l_features = lig_vox.reshape(lig_N[0], lig_N[1], lig_N[2], lig_vox.shape[1])

    # 组合两个体素化过后的数组
    features = np.concatenate((p_features, l_features), axis=3)
    
    return features

# %%
def get_pdb_features(ids, sets="refined"):
    """ 根据PDBid 进行体素化 并返回体素化结果x 和标签y """
    pdb_ids = []
    pdb_features = []

    # 逐一进行体素化，并使用tqdm生成进度条。
    for pdbid in tqdm(ids):
        # 根据PDBid获得文件路径
        protein_file = os.path.join(pdbbind_dir, pdbid, pdbid + "_protein.pdbqt")
        ligand_file = os.path.join(pdbbind_dir, pdbid, pdbid + "_ligand.mol2")

        # 若文件不存在则跳过
        if not os.path.isfile(protein_file) or not os.path.isfile(ligand_file):
            with open('.\\miss.log', 'a') as f:
                f.write(protein_file+ ' or '+ ligand_file+ ' not find\n')
            continue
        # 若文件不能体素化则输出错误，并跳过
        try:
            features = get_pdb_complex_feature(protein_file, ligand_file)
        except Exception as e:
            print("ERROR in ", pdbid , " ", str(e))
            with open('.\\error.log', 'a') as f:
                f.write("ERROR in "+ pdbid+ " "+ str(e)+ '\n')
            continue
        
        # 对应获得PDBid的列表和element feature的数组
        pdb_ids.append(pdbid)
        pdb_features.append(features)
    
    # 根据PDBid返回其对应的标签值（Ki, Kd, IC50）
    data_x = np.array(pdb_features, dtype=np.float32)
    data_y = np.array([pdbbind_dataset.sets[sets][_id] for _id in pdb_ids], dtype=np.float32)

    return data_x, data_y

# %%
def get_features():
    """ 返回数据库中的体素化结果x 并对应标签y值 """ 

    # 核心数据集选择
    core_ids = list(pdbbind_dataset.sets['core'].keys())
    # 精炼数据集选择
    #refined_ids = list(pdbbind_dataset.sets['refined'].keys()) 
    # 将精炼数据集和核心数据集独立
    #refined_ids = [i for i in refined_ids if i not in core_ids]
    
    # 执行批量体素化 
    print("Extracting features for the core set")
    core_x, core_y = get_pdb_features(core_ids, sets="core")
    #print("Extracting features for the refined set")
    #refined_x, refined_y = get_pdb_features(refined_ids)    
    
    return core_x, core_y

# %%
def main():
    # 核心数据集作为测试集
    test_x, test_y = get_features()
    # 划分训练集、验证集
    #train_x, valid_x, train_y, valid_y = train_test_split(train_x, train_y, test_size=0.2, random_state=1)
    print("Shapes in the training, test and the validation set: ", test_x.shape)

    # 切片蛋白体素和小分子体素并分别保存
    #train_xp, train_xl = train_x[..., 0:8], train_x[..., 8:]
    #valid_xp, valid_xl = valid_x[..., 0:8], valid_x[..., 8:]
    test_xp, test_xl = test_x[..., 0:8], test_x[..., 8:]

    # 保存
    print("Saving the data in pretest.h5")
    h5f = h5py.File(os.path.join(data_dir, "test1.h5"), 'w')
    '''
    h5f.create_dataset('train_xp', data=train_xp)
    h5f.create_dataset('train_xl', data=train_xl)
    h5f.create_dataset('train_y', data=train_y)
    h5f.create_dataset('valid_xp', data=valid_xp)
    h5f.create_dataset('valid_xl', data=valid_xl)
    h5f.create_dataset('valid_y', data=valid_y)
    '''
    h5f.create_dataset('test_xp', data=test_xp)
    h5f.create_dataset('test_xl', data=test_xl)
    h5f.create_dataset('test_y', data=test_y)
    h5f.close()

# %%
if __name__=="__main__":main()
# Out:
# Extracting features for the core set
#   0%|          | 0/290 [00:00<?, ?it/s]2023-08-31 14:21:39,997 - moleculekit.smallmol.smallmol - INFO - Adding any missing hydrogens (fixHs=True)
# 2023-08-31 14:21:40,025 - moleculekit.molecule - INFO - Removed 467 atoms. 2099 atoms remaining in the molecule.
# 2023-08-31 14:21:40,047 - moleculekit.molecule - INFO - Removed 4 atoms. 2095 atoms remaining in the molecule.
# 2023-08-31 14:21:43,361 - moleculekit.tools.preparation - WARNING - Dubious protonation state: the pKa of 2 residues is within 1.0 units of pH 7.4.
# 2023-08-31 14:21:43,362 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS    67 A (pKa= 6.90)
# 2023-08-31 14:21:43,364 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS    67 B (pKa= 6.75)
# 2023-08-31 14:21:43,934 - moleculekit.tools.atomtyper - INFO - Checking validity of Molecule before atomtyping. If it gives incorrect results or to improve performance disable it with validitychecks=False. Most of these checks can be passed by using the moleculekit.atomtyper.prepareProteinForAtomtyping function. But make sure you understand what you are doing.
#   0%|          | 1/290 [00:05<27:40,  5.75s/it]2023-08-31 14:21:45,765 - moleculekit.smallmol.smallmol - INFO - Adding any missing hydrogens (fixHs=True)
# 2023-08-31 14:21:45,798 - moleculekit.molecule - INFO - Removed 603 atoms. 2800 atoms remaining in the molecule.
# 2023-08-31 14:21:50,028 - moleculekit.tools.preparation - WARNING - Dubious protonation state: the pKa of 5 residues is within 1.0 units of pH 7.4.
# 2023-08-31 14:21:50,030 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    LYS    67 A (pKa= 8.24)
# 2023-08-31 14:21:50,031 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    TYR   150 A (pKa= 7.66)
# 2023-08-31 14:21:50,032 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   186 A (pKa= 6.51)
# 2023-08-31 14:21:50,034 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU   219 A (pKa= 6.73)
# 2023-08-31 14:21:50,035 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    LYS   332 A (pKa= 8.27)
# 2023-08-31 14:21:50,542 - moleculekit.tools.atomtyper - INFO - Checking validity of Molecule before atomtyping. If it gives incorrect results or to improve performance disable it with validitychecks=False. Most of these checks can be passed by using the moleculekit.atomtyper.prepareProteinForAtomtyping function. But make sure you understand what you are doing.
#   1%|          | 2/290 [00:12<31:25,  6.55s/it]2023-08-31 14:21:52,822 - moleculekit.smallmol.smallmol - INFO - Adding any missing hydrogens (fixHs=True)
# 2023-08-31 14:21:52,841 - moleculekit.molecule - INFO - Removed 379 atoms. 1630 atoms remaining in the molecule.
# 2023-08-31 14:21:52,858 - moleculekit.molecule - INFO - Removed 1 atoms. 1629 atoms remaining in the molecule.
# 2023-08-31 14:21:55,540 - moleculekit.tools.preparation - WARNING - Dubious protonation state: the pKa of 4 residues is within 1.0 units of pH 7.4.
# 2023-08-31 14:21:55,541 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    TYR    39 A (pKa= 8.25)
# 2023-08-31 14:21:55,543 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS    57 A (pKa= 7.34)
# 2023-08-31 14:21:55,544 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU    70 A (pKa= 7.19)
# 2023-08-31 14:21:55,546 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    ASP   189 A (pKa= 6.46)
# 2023-08-31 14:21:55,797 - moleculekit.tools.atomtyper - INFO - Checking validity of Molecule before atomtyping. If it gives incorrect results or to improve performance disable it with validitychecks=False. Most of these checks can be passed by using the moleculekit.atomtyper.prepareProteinForAtomtyping function. But make sure you understand what you are doing.
#   1%|          | 3/290 [00:17<26:20,  5.51s/it]2023-08-31 14:21:57,306 - moleculekit.smallmol.smallmol - INFO - Adding any missing hydrogens (fixHs=True)
# 2023-08-31 14:21:57,399 - moleculekit.molecule - INFO - Removed 1765 atoms. 8182 atoms remaining in the molecule.
# 2023-08-31 14:21:57,489 - moleculekit.molecule - INFO - Removed 1 atoms. 8181 atoms remaining in the molecule.
# 2023-08-31 14:22:15,740 - moleculekit.tools.preparation - WARNING - Dubious protonation state: the pKa of 12 residues is within 1.0 units of pH 7.4.
# 2023-08-31 14:22:15,742 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   119 A (pKa= 7.23)
# 2023-08-31 14:22:15,744 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU   130 A (pKa= 7.23)
# 2023-08-31 14:22:15,745 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU   159 A (pKa= 6.76)
# 2023-08-31 14:22:15,747 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    LYS   325 A (pKa= 6.69)
# 2023-08-31 14:22:15,748 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    ASP   341 A (pKa= 7.64)
# 2023-08-31 14:22:15,749 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   387 A (pKa= 6.44)
# 2023-08-31 14:22:15,751 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   481 A (pKa= 7.06)
# 2023-08-31 14:22:15,753 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   643 A (pKa= 6.51)
# 2023-08-31 14:22:15,755 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    ASP   867 A (pKa= 7.68)
# 2023-08-31 14:22:15,757 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    ASP   930 A (pKa= 6.66)
# 2023-08-31 14:22:15,758 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS  1001 A (pKa= 6.96)
# 2023-08-31 14:22:15,760 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS  1022 A (pKa= 6.43)
# 2023-08-31 14:22:17,261 - moleculekit.tools.atomtyper - INFO - Checking validity of Molecule before atomtyping. If it gives incorrect results or to improve performance disable it with validitychecks=False. Most of these checks can be passed by using the moleculekit.atomtyper.prepareProteinForAtomtyping function. But make sure you understand what you are doing.
# ==============================
# *** Open Babel Warning  in OpenBabel::OBMol::PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is C:\Users\Able9\AppData\Local\Temp\tmpimgv32g3.pdb)
#   1%|▏         | 4/290 [00:49<1:17:20, 16.23s/it]2023-08-31 14:22:29,834 - moleculekit.smallmol.smallmol - INFO - Adding any missing hydrogens (fixHs=True)
# 2023-08-31 14:22:29,897 - moleculekit.molecule - INFO - Removed 893 atoms. 4205 atoms remaining in the molecule.
# 2023-08-31 14:22:36,791 - moleculekit.tools.preparation - WARNING - Dubious protonation state: the pKa of 7 residues is within 1.0 units of pH 7.4.
# 2023-08-31 14:22:36,791 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS     7 A (pKa= 6.46)
# 2023-08-31 14:22:36,791 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    LYS   145 A (pKa= 8.24)
# 2023-08-31 14:22:36,791 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    LYS   160 A (pKa= 8.22)
# 2023-08-31 14:22:36,791 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   222 A (pKa= 7.24)
# 2023-08-31 14:22:36,791 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS     7 B (pKa= 6.57)
# 2023-08-31 14:22:36,791 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    LYS   145 B (pKa= 8.17)
# 2023-08-31 14:22:36,791 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   222 B (pKa= 7.09)
# 2023-08-31 14:22:37,824 - moleculekit.tools.atomtyper - INFO - Checking validity of Molecule before atomtyping. If it gives incorrect results or to improve performance disable it with validitychecks=False. Most of these checks can be passed by using the moleculekit.atomtyper.prepareProteinForAtomtyping function. But make sure you understand what you are doing.
#   2%|▏         | 5/290 [01:02<1:10:14, 14.79s/it]2023-08-31 14:22:42,014 - moleculekit.smallmol.smallmol - INFO - Adding any missing hydrogens (fixHs=True)
# 2023-08-31 14:22:42,045 - moleculekit.molecule - INFO - Removed 437 atoms. 2046 atoms remaining in the molecule.
# 2023-08-31 14:22:42,061 - moleculekit.molecule - INFO - Removed 1 atoms. 2045 atoms remaining in the molecule.
# 2023-08-31 14:22:45,360 - moleculekit.tools.preparation - WARNING - Dubious protonation state: the pKa of 3 residues is within 1.0 units of pH 7.4.
# 2023-08-31 14:22:45,360 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS     4 A (pKa= 6.47)
# 2023-08-31 14:22:45,360 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS    36 A (pKa= 6.75)
# 2023-08-31 14:22:45,360 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS    96 A (pKa= 8.13)
# 2023-08-31 14:22:45,673 - moleculekit.tools.atomtyper - INFO - Checking validity of Molecule before atomtyping. If it gives incorrect results or to improve performance disable it with validitychecks=False. Most of these checks can be passed by using the moleculekit.atomtyper.prepareProteinForAtomtyping function. But make sure you understand what you are doing.
# ==============================
# *** Open Babel Warning  in OpenBabel::OBMol::PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is C:\Users\Able9\AppData\Local\Temp\tmpv0_hqrr9.pdb)
#   2%|▏         | 6/290 [01:07<54:42, 11.56s/it]  2023-08-31 14:22:47,299 - moleculekit.smallmol.smallmol - INFO - Adding any missing hydrogens (fixHs=True)
# 2023-08-31 14:22:47,315 - moleculekit.molecule - INFO - Removed 463 atoms. 1954 atoms remaining in the molecule.
# 2023-08-31 14:22:50,285 - moleculekit.tools.preparation - WARNING - Dubious protonation state: the pKa of 1 residues is within 1.0 units of pH 7.4.
# 2023-08-31 14:22:50,285 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    LYS   234 A (pKa= 6.80)
# 2023-08-31 14:22:50,566 - moleculekit.tools.atomtyper - INFO - Checking validity of Molecule before atomtyping. If it gives incorrect results or to improve performance disable it with validitychecks=False. Most of these checks can be passed by using the moleculekit.atomtyper.prepareProteinForAtomtyping function. But make sure you understand what you are doing.
#   2%|▏         | 7/290 [01:12<44:12,  9.37s/it]2023-08-31 14:22:52,129 - moleculekit.smallmol.smallmol - INFO - Adding any missing hydrogens (fixHs=True)
# 2023-08-31 14:22:52,129 - moleculekit.molecule - INFO - Removed 237 atoms. 951 atoms remaining in the molecule.
# 2023-08-31 14:22:53,898 - moleculekit.tools.preparation - WARNING - Dubious protonation state: the pKa of 2 residues is within 1.0 units of pH 7.4.
# 2023-08-31 14:22:53,898 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   105 A (pKa= 7.06)
# 2023-08-31 14:22:53,898 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   119 A (pKa= 6.64)
# 2023-08-31 14:22:54,039 - moleculekit.tools.atomtyper - INFO - Checking validity of Molecule before atomtyping. If it gives incorrect results or to improve performance disable it with validitychecks=False. Most of these checks can be passed by using the moleculekit.atomtyper.prepareProteinForAtomtyping function. But make sure you understand what you are doing.
#   3%|▎         | 8/290 [01:14<34:00,  7.24s/it]2023-08-31 14:22:55,306 - moleculekit.smallmol.smallmol - INFO - Adding any missing hydrogens (fixHs=True)
# 2023-08-31 14:22:55,447 - moleculekit.molecule - INFO - Removed 2944 atoms. 13194 atoms remaining in the molecule.
# 2023-08-31 14:23:33,203 - moleculekit.tools.preparation - WARNING - The following residues have not been optimized: LLP
# 2023-08-31 14:23:36,315 - moleculekit.tools.preparation - WARNING - Dubious protonation state: the pKa of 18 residues is within 1.0 units of pH 7.4.
# 2023-08-31 14:23:36,315 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU   126 A (pKa= 6.61)
# 2023-08-31 14:23:36,315 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    CYS   142 A (pKa= 8.23)
# 2023-08-31 14:23:36,315 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    ASP   180 A (pKa= 7.75)
# 2023-08-31 14:23:36,315 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    LYS   191 A (pKa= 7.71)
# 2023-08-31 14:23:36,315 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    LYS   538 A (pKa= 7.45)
# 2023-08-31 14:23:36,315 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   556 A (pKa= 6.61)
# 2023-08-31 14:23:36,315 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    LYS   608 A (pKa= 6.85)
# 2023-08-31 14:23:36,331 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   632 A (pKa= 7.13)
# 2023-08-31 14:23:36,331 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    ASP   693 A (pKa= 6.53)
# 2023-08-31 14:23:36,331 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU   126 B (pKa= 6.61)
# 2023-08-31 14:23:36,331 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    CYS   142 B (pKa= 8.23)
# 2023-08-31 14:23:36,331 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    ASP   180 B (pKa= 7.75)
# 2023-08-31 14:23:36,331 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    LYS   191 B (pKa= 7.71)
# 2023-08-31 14:23:36,331 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    LYS   538 B (pKa= 7.45)
# 2023-08-31 14:23:36,331 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   556 B (pKa= 6.61)
# 2023-08-31 14:23:36,331 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    LYS   608 B (pKa= 6.85)
# 2023-08-31 14:23:36,331 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   632 B (pKa= 7.13)
# 2023-08-31 14:23:36,347 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    ASP   693 B (pKa= 6.53)
# 2023-08-31 14:23:41,688 - moleculekit.tools.atomtyper - INFO - Checking validity of Molecule before atomtyping. If it gives incorrect results or to improve performance disable it with validitychecks=False. Most of these checks can be passed by using the moleculekit.atomtyper.prepareProteinForAtomtyping function. But make sure you understand what you are doing.
#   3%|▎         | 9/290 [02:31<2:16:06, 29.06s/it]2023-08-31 14:24:11,906 - moleculekit.smallmol.smallmol - INFO - Adding any missing hydrogens (fixHs=True)
# 2023-08-31 14:24:11,938 - moleculekit.molecule - INFO - Removed 603 atoms. 2800 atoms remaining in the molecule.
# 2023-08-31 14:24:16,189 - moleculekit.tools.preparation - WARNING - Dubious protonation state: the pKa of 5 residues is within 1.0 units of pH 7.4.
# 2023-08-31 14:24:16,191 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS    13 A (pKa= 6.44)
# 2023-08-31 14:24:16,192 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    LYS    67 A (pKa= 8.31)
# 2023-08-31 14:24:16,193 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   186 A (pKa= 6.51)
# 2023-08-31 14:24:16,195 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU   219 A (pKa= 6.93)
# 2023-08-31 14:24:16,197 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    LYS   315 A (pKa= 7.17)
# 2023-08-31 14:24:16,607 - moleculekit.tools.atomtyper - INFO - Checking validity of Molecule before atomtyping. If it gives incorrect results or to improve performance disable it with validitychecks=False. Most of these checks can be passed by using the moleculekit.atomtyper.prepareProteinForAtomtyping function. But make sure you understand what you are doing.
#   3%|▎         | 10/290 [02:38<1:43:46, 22.24s/it]2023-08-31 14:24:18,831 - moleculekit.smallmol.smallmol - INFO - Adding any missing hydrogens (fixHs=True)
# 2023-08-31 14:24:18,855 - moleculekit.molecule - INFO - Removed 422 atoms. 1893 atoms remaining in the molecule.
# 2023-08-31 14:24:21,923 - moleculekit.tools.preparation - WARNING - Dubious protonation state: the pKa of 4 residues is within 1.0 units of pH 7.4.
# 2023-08-31 14:24:21,924 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS    57 A (pKa= 7.37)
# 2023-08-31 14:24:21,926 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS    99 A (pKa= 6.56)
# 2023-08-31 14:24:21,927 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   170B A (pKa= 6.41)
# 2023-08-31 14:24:21,928 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    ASP   189 A (pKa= 6.77)
# 2023-08-31 14:24:22,271 - moleculekit.tools.atomtyper - INFO - Checking validity of Molecule before atomtyping. If it gives incorrect results or to improve performance disable it with validitychecks=False. Most of these checks can be passed by using the moleculekit.atomtyper.prepareProteinForAtomtyping function. But make sure you understand what you are doing.
#   4%|▍         | 11/290 [02:43<1:18:49, 16.95s/it]2023-08-31 14:24:23,821 - moleculekit.smallmol.smallmol - INFO - Adding any missing hydrogens (fixHs=True)
# 2023-08-31 14:24:23,849 - moleculekit.molecule - INFO - Removed 534 atoms. 2429 atoms remaining in the molecule.
# 2023-08-31 14:24:23,873 - moleculekit.molecule - INFO - Removed 5 atoms. 2424 atoms remaining in the molecule.
# 2023-08-31 14:24:28,077 - moleculekit.tools.preparation - WARNING - Dubious protonation state: the pKa of 3 residues is within 1.0 units of pH 7.4.
# 2023-08-31 14:24:28,079 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   105 A (pKa= 7.77)
# 2023-08-31 14:24:28,080 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   146 A (pKa= 6.97)
# 2023-08-31 14:24:28,081 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    ASP   213 A (pKa= 6.49)
# 2023-08-31 14:24:28,434 - moleculekit.tools.atomtyper - INFO - Checking validity of Molecule before atomtyping. If it gives incorrect results or to improve performance disable it with validitychecks=False. Most of these checks can be passed by using the moleculekit.atomtyper.prepareProteinForAtomtyping function. But make sure you understand what you are doing.
# ==============================
# *** Open Babel Warning  in OpenBabel::OBMol::PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is C:\Users\Able9\AppData\Local\Temp\tmp2_2ymikd.pdb)
#   4%|▍         | 12/290 [02:50<1:03:51, 13.78s/it]2023-08-31 14:24:30,313 - moleculekit.smallmol.smallmol - INFO - Adding any missing hydrogens (fixHs=True)
# 2023-08-31 14:24:30,329 - moleculekit.molecule - INFO - Removed 257 atoms. 1243 atoms remaining in the molecule.
# 2023-08-31 14:24:30,342 - moleculekit.molecule - INFO - Removed 5 atoms. 1238 atoms remaining in the molecule.
# 2023-08-31 14:24:32,377 - moleculekit.tools.preparation - WARNING - Dubious protonation state: the pKa of 5 residues is within 1.0 units of pH 7.4.
# 2023-08-31 14:24:32,379 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   168 A (pKa= 7.03)
# 2023-08-31 14:24:32,380 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   172 A (pKa= 6.43)
# 2023-08-31 14:24:32,381 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU   199 A (pKa= 6.67)
# 2023-08-31 14:24:32,383 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU   201 A (pKa= 6.71)
# 2023-08-31 14:24:32,384 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU   219 A (pKa= 8.19)
# 2023-08-31 14:24:32,566 - moleculekit.tools.atomtyper - INFO - Checking validity of Molecule before atomtyping. If it gives incorrect results or to improve performance disable it with validitychecks=False. Most of these checks can be passed by using the moleculekit.atomtyper.prepareProteinForAtomtyping function. But make sure you understand what you are doing.
#   4%|▍         | 13/290 [02:53<48:46, 10.57s/it]  2023-08-31 14:24:33,517 - moleculekit.smallmol.smallmol - INFO - Adding any missing hydrogens (fixHs=True)
# 2023-08-31 14:24:33,544 - moleculekit.molecule - INFO - Removed 512 atoms. 2318 atoms remaining in the molecule.
# 2023-08-31 14:24:37,142 - moleculekit.tools.preparation - WARNING - Dubious protonation state: the pKa of 6 residues is within 1.0 units of pH 7.4.
# 2023-08-31 14:24:37,144 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU    92 A (pKa= 7.21)
# 2023-08-31 14:24:37,146 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   114 A (pKa= 6.83)
# 2023-08-31 14:24:37,147 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   183 A (pKa= 7.23)
# 2023-08-31 14:24:37,149 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU    92 B (pKa= 7.16)
# 2023-08-31 14:24:37,150 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   114 B (pKa= 6.83)
# 2023-08-31 14:24:37,151 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   183 B (pKa= 7.26)
# 2023-08-31 14:24:37,711 - moleculekit.tools.atomtyper - INFO - Checking validity of Molecule before atomtyping. If it gives incorrect results or to improve performance disable it with validitychecks=False. Most of these checks can be passed by using the moleculekit.atomtyper.prepareProteinForAtomtyping function. But make sure you understand what you are doing.
#   5%|▍         | 14/290 [02:59<42:28,  9.24s/it]2023-08-31 14:24:39,699 - moleculekit.smallmol.smallmol - INFO - Adding any missing hydrogens (fixHs=True)
# 2023-08-31 14:24:39,733 - moleculekit.molecule - INFO - Removed 655 atoms. 3107 atoms remaining in the molecule.
# 2023-08-31 14:24:39,762 - moleculekit.molecule - INFO - Removed 1 atoms. 3106 atoms remaining in the molecule.
# 2023-08-31 14:24:44,593 - moleculekit.tools.preparation - WARNING - Dubious protonation state: the pKa of 5 residues is within 1.0 units of pH 7.4.
# 2023-08-31 14:24:44,594 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    ASP    32 A (pKa= 7.66)
# 2023-08-31 14:24:44,595 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS    89 A (pKa= 6.49)
# 2023-08-31 14:24:44,595 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   362 A (pKa= 6.73)
# 2023-08-31 14:24:44,596 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   395 A (pKa= 7.20)
# 2023-08-31 14:24:44,597 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   397 A (pKa= 6.71)
# 2023-08-31 14:24:45,220 - moleculekit.tools.atomtyper - INFO - Checking validity of Molecule before atomtyping. If it gives incorrect results or to improve performance disable it with validitychecks=False. Most of these checks can be passed by using the moleculekit.atomtyper.prepareProteinForAtomtyping function. But make sure you understand what you are doing.
#   5%|▌         | 15/290 [03:07<40:54,  8.93s/it]2023-08-31 14:24:47,860 - moleculekit.smallmol.smallmol - INFO - Adding any missing hydrogens (fixHs=True)
# 2023-08-31 14:24:47,884 - moleculekit.molecule - INFO - Removed 463 atoms. 1954 atoms remaining in the molecule.
# 2023-08-31 14:24:50,860 - moleculekit.tools.preparation - WARNING - Dubious protonation state: the pKa of 1 residues is within 1.0 units of pH 7.4.
# 2023-08-31 14:24:50,861 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    LYS   234 A (pKa= 6.83)
# 2023-08-31 14:24:51,155 - moleculekit.tools.atomtyper - INFO - Checking validity of Molecule before atomtyping. If it gives incorrect results or to improve performance disable it with validitychecks=False. Most of these checks can be passed by using the moleculekit.atomtyper.prepareProteinForAtomtyping function. But make sure you understand what you are doing.
#   6%|▌         | 16/290 [03:12<35:09,  7.70s/it]2023-08-31 14:24:52,728 - moleculekit.smallmol.smallmol - INFO - Adding any missing hydrogens (fixHs=True)
# 2023-08-31 14:24:52,763 - moleculekit.molecule - INFO - Removed 543 atoms. 2638 atoms remaining in the molecule.
# 2023-08-31 14:24:52,790 - moleculekit.molecule - INFO - Removed 2 atoms. 2636 atoms remaining in the molecule.
# 2023-08-31 14:24:57,261 - moleculekit.tools.preparation - WARNING - Dubious protonation state: the pKa of 3 residues is within 1.0 units of pH 7.4.
# 2023-08-31 14:24:57,263 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    CYS   502 A (pKa= 6.95)
# 2023-08-31 14:24:57,264 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   529 A (pKa= 7.13)
# 2023-08-31 14:24:57,265 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU   592 A (pKa= 6.99)
# 2023-08-31 14:24:57,662 - moleculekit.tools.atomtyper - INFO - Checking validity of Molecule before atomtyping. If it gives incorrect results or to improve performance disable it with validitychecks=False. Most of these checks can be passed by using the moleculekit.atomtyper.prepareProteinForAtomtyping function. But make sure you understand what you are doing.
# ==============================
# *** Open Babel Warning  in OpenBabel::OBMol::PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is C:\Users\Able9\AppData\Local\Temp\tmpl4oomtm3.pdb)
#   6%|▌         | 17/290 [03:19<34:09,  7.51s/it]2023-08-31 14:24:59,861 - moleculekit.smallmol.smallmol - INFO - Adding any missing hydrogens (fixHs=True)
# 2023-08-31 14:24:59,997 - moleculekit.molecule - INFO - Removed 927 atoms. 4055 atoms remaining in the molecule.
# 2023-08-31 14:25:07,311 - moleculekit.tools.preparation - WARNING - Dubious protonation state: the pKa of 2 residues is within 1.0 units of pH 7.4.
# 2023-08-31 14:25:07,312 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU   402 A (pKa= 6.65)
# 2023-08-31 14:25:07,314 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU   402 B (pKa= 6.62)
# 2023-08-31 14:25:08,208 - moleculekit.tools.atomtyper - INFO - Checking validity of Molecule before atomtyping. If it gives incorrect results or to improve performance disable it with validitychecks=False. Most of these checks can be passed by using the moleculekit.atomtyper.prepareProteinForAtomtyping function. But make sure you understand what you are doing.
#   6%|▌         | 18/290 [03:32<41:09,  9.08s/it]2023-08-31 14:25:12,661 - moleculekit.smallmol.smallmol - INFO - Adding any missing hydrogens (fixHs=True)
# 2023-08-31 14:25:12,718 - moleculekit.molecule - INFO - Removed 1078 atoms. 4992 atoms remaining in the molecule.
# 2023-08-31 14:25:12,764 - moleculekit.molecule - INFO - Removed 4 atoms. 4988 atoms remaining in the molecule.
# 2023-08-31 14:25:21,173 - moleculekit.tools.preparation - WARNING - Dubious protonation state: the pKa of 4 residues is within 1.0 units of pH 7.4.
# 2023-08-31 14:25:21,174 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS    89 A (pKa= 6.93)
# 2023-08-31 14:25:21,176 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU   252 A (pKa= 7.34)
# 2023-08-31 14:25:21,177 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS    89 B (pKa= 6.97)
# 2023-08-31 14:25:21,178 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU   252 B (pKa= 7.41)
# 2023-08-31 14:25:22,229 - moleculekit.tools.atomtyper - INFO - Checking validity of Molecule before atomtyping. If it gives incorrect results or to improve performance disable it with validitychecks=False. Most of these checks can be passed by using the moleculekit.atomtyper.prepareProteinForAtomtyping function. But make sure you understand what you are doing.
#   7%|▋         | 19/290 [03:47<49:20, 10.93s/it]2023-08-31 14:25:27,748 - moleculekit.smallmol.smallmol - INFO - Adding any missing hydrogens (fixHs=True)
# 2023-08-31 14:25:27,769 - moleculekit.molecule - INFO - Removed 356 atoms. 1531 atoms remaining in the molecule.
# 2023-08-31 14:25:27,784 - moleculekit.molecule - INFO - Removed 1 atoms. 1530 atoms remaining in the molecule.
# 2023-08-31 14:25:30,568 - moleculekit.tools.preparation - WARNING - Dubious protonation state: the pKa of 1 residues is within 1.0 units of pH 7.4.
# 2023-08-31 14:25:30,570 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    CYS   176 A (pKa= 7.73)
# 2023-08-31 14:25:30,905 - moleculekit.tools.atomtyper - INFO - Checking validity of Molecule before atomtyping. If it gives incorrect results or to improve performance disable it with validitychecks=False. Most of these checks can be passed by using the moleculekit.atomtyper.prepareProteinForAtomtyping function. But make sure you understand what you are doing.
#   7%|▋         | 20/290 [03:52<40:14,  8.94s/it]2023-08-31 14:25:32,117 - moleculekit.smallmol.smallmol - INFO - Adding any missing hydrogens (fixHs=True)
# 2023-08-31 14:25:32,154 - moleculekit.molecule - INFO - Removed 720 atoms. 3254 atoms remaining in the molecule.
# 2023-08-31 14:25:32,187 - moleculekit.molecule - INFO - Removed 2 atoms. 3252 atoms remaining in the molecule.
# 2023-08-31 14:25:37,729 - moleculekit.tools.preparation - WARNING - Dubious protonation state: the pKa of 2 residues is within 1.0 units of pH 7.4.
# 2023-08-31 14:25:37,730 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    ASP    54 A (pKa= 6.49)
# 2023-08-31 14:25:37,731 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    ASP    54 B (pKa= 6.80)
# 2023-08-31 14:25:38,284 - moleculekit.tools.atomtyper - INFO - Checking validity of Molecule before atomtyping. If it gives incorrect results or to improve performance disable it with validitychecks=False. Most of these checks can be passed by using the moleculekit.atomtyper.prepareProteinForAtomtyping function. But make sure you understand what you are doing.
#   7%|▋         | 21/290 [04:01<40:38,  9.06s/it]2023-08-31 14:25:41,696 - moleculekit.smallmol.smallmol - INFO - Adding any missing hydrogens (fixHs=True)
# 2023-08-31 14:25:41,738 - moleculekit.molecule - INFO - Removed 569 atoms. 2748 atoms remaining in the molecule.
# 2023-08-31 14:25:46,268 - moleculekit.tools.preparation - WARNING - Dubious protonation state: the pKa of 4 residues is within 1.0 units of pH 7.4.
# 2023-08-31 14:25:46,270 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    LYS    67 B (pKa= 8.17)
# 2023-08-31 14:25:46,271 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    TYR   150 B (pKa= 7.69)
# 2023-08-31 14:25:46,272 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   186 B (pKa= 7.44)
# 2023-08-31 14:25:46,273 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU   219 B (pKa= 7.11)
# 2023-08-31 14:25:46,693 - moleculekit.tools.atomtyper - INFO - Checking validity of Molecule before atomtyping. If it gives incorrect results or to improve performance disable it with validitychecks=False. Most of these checks can be passed by using the moleculekit.atomtyper.prepareProteinForAtomtyping function. But make sure you understand what you are doing.
# ==============================
# *** Open Babel Warning  in OpenBabel::OBMol::PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is C:\Users\Able9\AppData\Local\Temp\tmpwhs3qz4g.pdb)
#   8%|▊         | 22/290 [04:09<38:36,  8.65s/it]2023-08-31 14:25:49,658 - moleculekit.smallmol.smallmol - INFO - Adding any missing hydrogens (fixHs=True)
# 2023-08-31 14:25:49,848 - moleculekit.molecule - INFO - Removed 3614 atoms. 16864 atoms remaining in the molecule.
# 2023-08-31 14:26:44,464 - moleculekit.tools.preparation - WARNING - Dubious protonation state: the pKa of 37 residues is within 1.0 units of pH 7.4.
# 2023-08-31 14:26:44,465 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    ASP    37 A (pKa= 8.11)
# 2023-08-31 14:26:44,466 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU    54 A (pKa= 7.41)
# 2023-08-31 14:26:44,467 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU    92 A (pKa= 7.24)
# 2023-08-31 14:26:44,468 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    ASP   195 A (pKa= 6.77)
# 2023-08-31 14:26:44,470 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    ASP    37 B (pKa= 7.49)
# 2023-08-31 14:26:44,472 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU    54 B (pKa= 7.06)
# 2023-08-31 14:26:44,473 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU    92 B (pKa= 7.05)
# 2023-08-31 14:26:44,474 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    ASP   195 B (pKa= 6.75)
# 2023-08-31 14:26:44,475 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    ASP    37 C (pKa= 8.25)
# 2023-08-31 14:26:44,476 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU    54 C (pKa= 7.12)
# 2023-08-31 14:26:44,478 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU    92 C (pKa= 7.01)
# 2023-08-31 14:26:44,479 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    ASP    37 D (pKa= 8.08)
# 2023-08-31 14:26:44,480 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU    54 D (pKa= 7.10)
# 2023-08-31 14:26:44,482 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU    92 D (pKa= 7.09)
# 2023-08-31 14:26:44,483 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    ASP   195 D (pKa= 6.53)
# 2023-08-31 14:26:44,484 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    ASP    37 E (pKa= 7.58)
# 2023-08-31 14:26:44,485 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU    54 E (pKa= 7.08)
# 2023-08-31 14:26:44,487 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU    92 E (pKa= 6.99)
# 2023-08-31 14:26:44,489 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    ASP    37 F (pKa= 8.27)
# 2023-08-31 14:26:44,490 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU    54 F (pKa= 7.08)
# 2023-08-31 14:26:44,491 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU    92 F (pKa= 7.02)
# 2023-08-31 14:26:44,492 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    ASP   195 F (pKa= 6.61)
# 2023-08-31 14:26:44,492 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    ASP    37 G (pKa= 8.19)
# 2023-08-31 14:26:44,493 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU    54 G (pKa= 7.10)
# 2023-08-31 14:26:44,494 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU    92 G (pKa= 7.10)
# 2023-08-31 14:26:44,495 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    ASP   131 G (pKa= 8.03)
# 2023-08-31 14:26:44,496 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    ASP    37 H (pKa= 7.54)
# 2023-08-31 14:26:44,497 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU    54 H (pKa= 7.04)
# 2023-08-31 14:26:44,499 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU    92 H (pKa= 7.05)
# 2023-08-31 14:26:44,501 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   185 H (pKa= 6.47)
# 2023-08-31 14:26:44,502 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    ASP    37 I (pKa= 8.16)
# 2023-08-31 14:26:44,503 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU    54 I (pKa= 7.10)
# 2023-08-31 14:26:44,504 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU    92 I (pKa= 6.85)
# 2023-08-31 14:26:44,507 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    ASP   131 I (pKa= 7.58)
# 2023-08-31 14:26:44,508 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    ASP    37 J (pKa= 7.47)
# 2023-08-31 14:26:44,510 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU    54 J (pKa= 7.14)
# 2023-08-31 14:26:44,511 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU    92 J (pKa= 7.06)
# 2023-08-31 14:26:50,684 - moleculekit.tools.atomtyper - INFO - Checking validity of Molecule before atomtyping. If it gives incorrect results or to improve performance disable it with validitychecks=False. Most of these checks can be passed by using the moleculekit.atomtyper.prepareProteinForAtomtyping function. But make sure you understand what you are doing.
#   8%|▊         | 23/290 [06:05<3:01:53, 40.87s/it]2023-08-31 14:27:45,229 - moleculekit.smallmol.smallmol - INFO - Adding any missing hydrogens (fixHs=True)
# 2023-08-31 14:27:45,277 - moleculekit.molecule - INFO - Removed 905 atoms. 4359 atoms remaining in the molecule.
# 2023-08-31 14:27:52,636 - moleculekit.tools.preparation - WARNING - Dubious protonation state: the pKa of 3 residues is within 1.0 units of pH 7.4.
# 2023-08-31 14:27:52,636 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS    58 A (pKa= 6.52)
# 2023-08-31 14:27:52,636 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU   315 A (pKa= 7.60)
# 2023-08-31 14:27:52,640 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   549 A (pKa= 6.90)
# 2023-08-31 14:27:53,408 - moleculekit.tools.atomtyper - INFO - Checking validity of Molecule before atomtyping. If it gives incorrect results or to improve performance disable it with validitychecks=False. Most of these checks can be passed by using the moleculekit.atomtyper.prepareProteinForAtomtyping function. But make sure you understand what you are doing.
#   8%|▊         | 24/290 [06:17<2:23:06, 32.28s/it]2023-08-31 14:27:57,369 - moleculekit.smallmol.smallmol - INFO - Adding any missing hydrogens (fixHs=True)
# 2023-08-31 14:27:57,397 - moleculekit.molecule - INFO - Removed 509 atoms. 2232 atoms remaining in the molecule.
# 2023-08-31 14:28:00,774 - moleculekit.tools.preparation - WARNING - Dubious protonation state: the pKa of 1 residues is within 1.0 units of pH 7.4.
# 2023-08-31 14:28:00,778 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS    57 H (pKa= 7.11)
# 2023-08-31 14:28:01,301 - moleculekit.tools.atomtyper - INFO - Checking validity of Molecule before atomtyping. If it gives incorrect results or to improve performance disable it with validitychecks=False. Most of these checks can be passed by using the moleculekit.atomtyper.prepareProteinForAtomtyping function. But make sure you understand what you are doing.
#   9%|▊         | 25/290 [06:23<1:47:34, 24.36s/it]2023-08-31 14:28:03,270 - moleculekit.smallmol.smallmol - INFO - Adding any missing hydrogens (fixHs=True)
# 2023-08-31 14:28:03,298 - moleculekit.molecule - INFO - Removed 512 atoms. 2318 atoms remaining in the molecule.
# 2023-08-31 14:28:06,957 - moleculekit.tools.preparation - WARNING - Dubious protonation state: the pKa of 6 residues is within 1.0 units of pH 7.4.
# 2023-08-31 14:28:06,957 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU    92 A (pKa= 7.07)
# 2023-08-31 14:28:06,961 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   114 A (pKa= 6.80)
# 2023-08-31 14:28:06,961 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   183 A (pKa= 7.34)
# 2023-08-31 14:28:06,961 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU    92 B (pKa= 7.13)
# 2023-08-31 14:28:06,961 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   114 B (pKa= 6.81)
# 2023-08-31 14:28:06,965 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   183 B (pKa= 7.17)
# 2023-08-31 14:28:07,549 - moleculekit.tools.atomtyper - INFO - Checking validity of Molecule before atomtyping. If it gives incorrect results or to improve performance disable it with validitychecks=False. Most of these checks can be passed by using the moleculekit.atomtyper.prepareProteinForAtomtyping function. But make sure you understand what you are doing.
#   9%|▉         | 26/290 [06:29<1:23:25, 18.96s/it]2023-08-31 14:28:09,669 - moleculekit.smallmol.smallmol - INFO - Adding any missing hydrogens (fixHs=True)
# 2023-08-31 14:28:09,720 - moleculekit.molecule - INFO - Removed 881 atoms. 4174 atoms remaining in the molecule.
# 2023-08-31 14:28:16,396 - moleculekit.tools.preparation - WARNING - Dubious protonation state: the pKa of 5 residues is within 1.0 units of pH 7.4.
# 2023-08-31 14:28:16,397 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS     7 A (pKa= 6.49)
# 2023-08-31 14:28:16,399 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    LYS   145 A (pKa= 8.18)
# 2023-08-31 14:28:16,399 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS     7 B (pKa= 6.48)
# 2023-08-31 14:28:16,401 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    LYS   145 B (pKa= 8.15)
# 2023-08-31 14:28:16,403 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   222 B (pKa= 7.15)
# 2023-08-31 14:28:17,390 - moleculekit.tools.atomtyper - INFO - Checking validity of Molecule before atomtyping. If it gives incorrect results or to improve performance disable it with validitychecks=False. Most of these checks can be passed by using the moleculekit.atomtyper.prepareProteinForAtomtyping function. But make sure you understand what you are doing.
#   9%|▉         | 27/290 [06:41<1:14:13, 16.93s/it]2023-08-31 14:28:21,847 - moleculekit.smallmol.smallmol - INFO - Adding any missing hydrogens (fixHs=True)
# 2023-08-31 14:28:21,880 - moleculekit.molecule - INFO - Removed 548 atoms. 2653 atoms remaining in the molecule.
# 2023-08-31 14:28:21,909 - moleculekit.molecule - INFO - Removed 2 atoms. 2651 atoms remaining in the molecule.
# 2023-08-31 14:28:27,391 - moleculekit.tools.preparation - WARNING - Dubious protonation state: the pKa of 3 residues is within 1.0 units of pH 7.4.
# 2023-08-31 14:28:27,392 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    CYS   502 A (pKa= 6.90)
# 2023-08-31 14:28:27,394 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   529 A (pKa= 7.16)
# 2023-08-31 14:28:27,396 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU   592 A (pKa= 7.07)
# 2023-08-31 14:28:27,904 - moleculekit.tools.atomtyper - INFO - Checking validity of Molecule before atomtyping. If it gives incorrect results or to improve performance disable it with validitychecks=False. Most of these checks can be passed by using the moleculekit.atomtyper.prepareProteinForAtomtyping function. But make sure you understand what you are doing.
# ==============================
# *** Open Babel Warning  in OpenBabel::OBMol::PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is C:\Users\Able9\AppData\Local\Temp\tmppu0_c91j.pdb)
#  10%|▉         | 28/290 [06:50<1:02:52, 14.40s/it]2023-08-31 14:28:30,657 - moleculekit.smallmol.smallmol - INFO - Adding any missing hydrogens (fixHs=True)
# 2023-08-31 14:28:30,887 - moleculekit.molecule - INFO - Removed 2948 atoms. 13208 atoms remaining in the molecule.
# 2023-08-31 14:29:25,205 - moleculekit.tools.preparation - WARNING - The following residues have not been optimized: LLP
# 2023-08-31 14:29:28,093 - moleculekit.tools.preparation - WARNING - Dubious protonation state: the pKa of 20 residues is within 1.0 units of pH 7.4.
# 2023-08-31 14:29:28,093 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU   126 A (pKa= 6.51)
# 2023-08-31 14:29:28,097 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    CYS   142 A (pKa= 8.25)
# 2023-08-31 14:29:28,097 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    ASP   180 A (pKa= 7.81)
# 2023-08-31 14:29:28,097 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    LYS   191 A (pKa= 7.28)
# 2023-08-31 14:29:28,101 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    ASP   339 A (pKa= 6.80)
# 2023-08-31 14:29:28,101 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    LYS   538 A (pKa= 7.48)
# 2023-08-31 14:29:28,101 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   556 A (pKa= 6.88)
# 2023-08-31 14:29:28,105 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    LYS   608 A (pKa= 6.69)
# 2023-08-31 14:29:28,105 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   632 A (pKa= 6.89)
# 2023-08-31 14:29:28,105 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    ASP   693 A (pKa= 6.74)
# 2023-08-31 14:29:28,105 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU   126 B (pKa= 6.51)
# 2023-08-31 14:29:28,109 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    CYS   142 B (pKa= 8.25)
# 2023-08-31 14:29:28,109 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    ASP   180 B (pKa= 7.81)
# 2023-08-31 14:29:28,109 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    LYS   191 B (pKa= 7.28)
# 2023-08-31 14:29:28,113 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    ASP   339 B (pKa= 6.80)
# 2023-08-31 14:29:28,113 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    LYS   538 B (pKa= 7.48)
# 2023-08-31 14:29:28,113 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   556 B (pKa= 6.88)
# 2023-08-31 14:29:28,113 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    LYS   608 B (pKa= 6.69)
# 2023-08-31 14:29:28,113 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   632 B (pKa= 6.89)
# 2023-08-31 14:29:28,117 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    ASP   693 B (pKa= 6.74)
# 2023-08-31 14:29:33,439 - moleculekit.tools.atomtyper - INFO - Checking validity of Molecule before atomtyping. If it gives incorrect results or to improve performance disable it with validitychecks=False. Most of these checks can be passed by using the moleculekit.atomtyper.prepareProteinForAtomtyping function. But make sure you understand what you are doing.
#  10%|█         | 29/290 [08:23<2:45:41, 38.09s/it]2023-08-31 14:30:03,709 - moleculekit.smallmol.smallmol - INFO - Adding any missing hydrogens (fixHs=True)
# 2023-08-31 14:30:03,741 - moleculekit.molecule - INFO - Removed 540 atoms. 2626 atoms remaining in the molecule.
# 2023-08-31 14:30:03,765 - moleculekit.molecule - INFO - Removed 2 atoms. 2624 atoms remaining in the molecule.
# 2023-08-31 14:30:08,291 - moleculekit.tools.preparation - WARNING - Dubious protonation state: the pKa of 3 residues is within 1.0 units of pH 7.4.
# 2023-08-31 14:30:08,295 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    CYS   502 A (pKa= 6.56)
# 2023-08-31 14:30:08,295 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   529 A (pKa= 7.14)
# 2023-08-31 14:30:08,295 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU   592 A (pKa= 7.12)
# ...
# 2023-08-31 15:15:51,421 - moleculekit.tools.preparation - WARNING - Dubious protonation state: the pKa of 8 residues is within 1.0 units of pH 7.4.
# 2023-08-31 15:15:51,421 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   105 E (pKa= 7.80)
# 2023-08-31 15:15:51,434 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU   119 E (pKa= 7.31)
# 2023-08-31 15:15:51,436 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   146 E (pKa= 7.23)
# 2023-08-31 15:15:51,436 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   231 E (pKa= 7.93)
# 2023-08-31 15:15:51,438 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   105 A (pKa= 7.80)
# 2023-08-31 15:15:51,439 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU   119 A (pKa= 7.31)
# 2023-08-31 15:15:51,440 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   146 A (pKa= 7.23)
# 2023-08-31 15:15:51,441 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   231 A (pKa= 7.93)
# 2023-08-31 15:15:52,329 - moleculekit.tools.atomtyper - INFO - Checking validity of Molecule before atomtyping. If it gives incorrect results or to improve performance disable it with validitychecks=False. Most of these checks can be passed by using the moleculekit.atomtyper.prepareProteinForAtomtyping function. But make sure you understand what you are doing.
# ==============================
# *** Open Babel Warning  in OpenBabel::OBMol::PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is C:\Users\Able9\AppData\Local\Temp\tmp73qiozsd.pdb)
#  96%|█████████▌| 279/290 [54:17<03:06, 16.91s/it]2023-08-31 15:15:57,749 - moleculekit.smallmol.smallmol - INFO - Adding any missing hydrogens (fixHs=True)
# 2023-08-31 15:15:57,796 - moleculekit.molecule - INFO - Removed 778 atoms. 3823 atoms remaining in the molecule.
# 2023-08-31 15:15:57,843 - moleculekit.molecule - INFO - Removed 1 atoms. 3822 atoms remaining in the molecule.
# 2023-08-31 15:16:04,021 - moleculekit.tools.preparation - WARNING - Dubious protonation state: the pKa of 7 residues is within 1.0 units of pH 7.4.
# 2023-08-31 15:16:04,022 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   373 A (pKa= 7.11)
# 2023-08-31 15:16:04,024 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    LYS   472 A (pKa= 8.20)
# 2023-08-31 15:16:04,025 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   373 B (pKa= 6.94)
# 2023-08-31 15:16:04,025 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   474 B (pKa= 6.72)
# 2023-08-31 15:16:04,026 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   501 B (pKa= 6.59)
# 2023-08-31 15:16:04,027 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU   523 B (pKa= 6.48)
# 2023-08-31 15:16:04,028 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   550 B (pKa= 6.59)
# 2023-08-31 15:16:04,969 - moleculekit.tools.atomtyper - INFO - Checking validity of Molecule before atomtyping. If it gives incorrect results or to improve performance disable it with validitychecks=False. Most of these checks can be passed by using the moleculekit.atomtyper.prepareProteinForAtomtyping function. But make sure you understand what you are doing.
#  97%|█████████▋| 280/290 [54:28<02:31, 15.16s/it]2023-08-31 15:16:08,726 - moleculekit.smallmol.smallmol - INFO - Adding any missing hydrogens (fixHs=True)
# 2023-08-31 15:16:08,751 - moleculekit.molecule - INFO - Removed 461 atoms. 2081 atoms remaining in the molecule.
# 2023-08-31 15:16:11,974 - moleculekit.tools.preparation - WARNING - Dubious protonation state: the pKa of 2 residues is within 1.0 units of pH 7.4.
# 2023-08-31 15:16:11,975 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   248 A (pKa= 7.23)
# 2023-08-31 15:16:11,975 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU   321 A (pKa= 7.05)
# 2023-08-31 15:16:12,309 - moleculekit.tools.atomtyper - INFO - Checking validity of Molecule before atomtyping. If it gives incorrect results or to improve performance disable it with validitychecks=False. Most of these checks can be passed by using the moleculekit.atomtyper.prepareProteinForAtomtyping function. But make sure you understand what you are doing.
#  97%|█████████▋| 281/290 [54:34<01:49, 12.20s/it]2023-08-31 15:16:14,094 - moleculekit.smallmol.smallmol - INFO - Adding any missing hydrogens (fixHs=True)
# 2023-08-31 15:16:14,126 - moleculekit.molecule - INFO - Removed 640 atoms. 3043 atoms remaining in the molecule.
# 2023-08-31 15:16:18,801 - moleculekit.tools.preparation - WARNING - Dubious protonation state: the pKa of 2 residues is within 1.0 units of pH 7.4.
# 2023-08-31 15:16:18,802 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   137 A (pKa= 6.41)
# 2023-08-31 15:16:18,803 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU   387 A (pKa= 6.71)
# 2023-08-31 15:16:19,458 - moleculekit.tools.atomtyper - INFO - Checking validity of Molecule before atomtyping. If it gives incorrect results or to improve performance disable it with validitychecks=False. Most of these checks can be passed by using the moleculekit.atomtyper.prepareProteinForAtomtyping function. But make sure you understand what you are doing.
#  97%|█████████▋| 282/290 [54:42<01:27, 10.97s/it]2023-08-31 15:16:22,161 - moleculekit.smallmol.smallmol - INFO - Adding any missing hydrogens (fixHs=True)
# 2023-08-31 15:16:22,191 - moleculekit.molecule - INFO - Removed 492 atoms. 2206 atoms remaining in the molecule.
# 2023-08-31 15:16:22,214 - moleculekit.molecule - INFO - Removed 2 atoms. 2204 atoms remaining in the molecule.
# 2023-08-31 15:16:26,020 - moleculekit.tools.preparation - WARNING - Dubious protonation state: the pKa of 1 residues is within 1.0 units of pH 7.4.
# 2023-08-31 15:16:26,021 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS    57 H (pKa= 7.11)
# 2023-08-31 15:16:26,428 - moleculekit.tools.atomtyper - INFO - Checking validity of Molecule before atomtyping. If it gives incorrect results or to improve performance disable it with validitychecks=False. Most of these checks can be passed by using the moleculekit.atomtyper.prepareProteinForAtomtyping function. But make sure you understand what you are doing.
#  98%|█████████▊| 283/290 [54:46<01:03,  9.03s/it]2023-08-31 15:16:26,644 - moleculekit.smallmol.smallmol - INFO - Adding any missing hydrogens (fixHs=True)
# 2023-08-31 15:16:26,678 - moleculekit.molecule - INFO - Removed 536 atoms. 2588 atoms remaining in the molecule.
# 2023-08-31 15:16:26,708 - moleculekit.molecule - INFO - Removed 2 atoms. 2586 atoms remaining in the molecule.
# ERROR in  3utu   Found atoms with resnames ['VAL'] in the Molecule which can cause issues with the voxelization. Please make sure to only pass protein atoms and metals.
# 2023-08-31 15:16:31,150 - moleculekit.tools.preparation - WARNING - Dubious protonation state: the pKa of 2 residues is within 1.0 units of pH 7.4.
# 2023-08-31 15:16:31,151 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   519 B (pKa= 6.92)
# 2023-08-31 15:16:31,152 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU   582 B (pKa= 7.37)
# 2023-08-31 15:16:31,626 - moleculekit.tools.atomtyper - INFO - Checking validity of Molecule before atomtyping. If it gives incorrect results or to improve performance disable it with validitychecks=False. Most of these checks can be passed by using the moleculekit.atomtyper.prepareProteinForAtomtyping function. But make sure you understand what you are doing.
# ==============================
# *** Open Babel Warning  in OpenBabel::OBMol::PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is C:\Users\Able9\AppData\Local\Temp\tmp341bzgoc.pdb)
#  98%|█████████▊| 284/290 [54:53<00:50,  8.46s/it]2023-08-31 15:16:33,758 - moleculekit.smallmol.smallmol - INFO - Adding any missing hydrogens (fixHs=True)
# 2023-08-31 15:16:33,787 - moleculekit.molecule - INFO - Removed 508 atoms. 2221 atoms remaining in the molecule.
# 2023-08-31 15:16:33,809 - moleculekit.molecule - INFO - Removed 1 atoms. 2220 atoms remaining in the molecule.
# 2023-08-31 15:16:37,461 - moleculekit.tools.preparation - WARNING - Dubious protonation state: the pKa of 2 residues is within 1.0 units of pH 7.4.
# 2023-08-31 15:16:37,462 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS    57 A (pKa= 7.24)
# 2023-08-31 15:16:37,463 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    ASP    70 A (pKa= 7.61)
# 2023-08-31 15:16:37,906 - moleculekit.tools.atomtyper - INFO - Checking validity of Molecule before atomtyping. If it gives incorrect results or to improve performance disable it with validitychecks=False. Most of these checks can be passed by using the moleculekit.atomtyper.prepareProteinForAtomtyping function. But make sure you understand what you are doing.
#  98%|█████████▊| 285/290 [54:59<00:38,  7.70s/it]2023-08-31 15:16:39,685 - moleculekit.smallmol.smallmol - INFO - Adding any missing hydrogens (fixHs=True)
# 2023-08-31 15:16:39,709 - moleculekit.molecule - INFO - Removed 458 atoms. 2224 atoms remaining in the molecule.
# 2023-08-31 15:16:43,151 - moleculekit.tools.preparation - WARNING - Dubious protonation state: the pKa of 2 residues is within 1.0 units of pH 7.4.
# 2023-08-31 15:16:43,152 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   244 A (pKa= 6.91)
# 2023-08-31 15:16:43,153 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   305 A (pKa= 6.88)
# 2023-08-31 15:16:43,565 - moleculekit.tools.atomtyper - INFO - Checking validity of Molecule before atomtyping. If it gives incorrect results or to improve performance disable it with validitychecks=False. Most of these checks can be passed by using the moleculekit.atomtyper.prepareProteinForAtomtyping function. But make sure you understand what you are doing.
#  99%|█████████▊| 286/290 [55:05<00:28,  7.07s/it]2023-08-31 15:16:45,338 - moleculekit.smallmol.smallmol - INFO - Adding any missing hydrogens (fixHs=True)
# 2023-08-31 15:16:45,379 - moleculekit.molecule - INFO - Removed 733 atoms. 3467 atoms remaining in the molecule.
# 2023-08-31 15:16:50,921 - moleculekit.tools.preparation - WARNING - Dubious protonation state: the pKa of 6 residues is within 1.0 units of pH 7.4.
# 2023-08-31 15:16:50,922 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS    65 A (pKa= 6.56)
# 2023-08-31 15:16:50,923 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU   174 A (pKa= 7.43)
# 2023-08-31 15:16:50,924 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   231 A (pKa= 6.65)
# 2023-08-31 15:16:50,925 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS     0 B (pKa= 6.42)
# 2023-08-31 15:16:50,926 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS    65 B (pKa= 6.79)
# 2023-08-31 15:16:50,927 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU   174 B (pKa= 7.72)
# 2023-08-31 15:16:51,580 - moleculekit.tools.atomtyper - INFO - Checking validity of Molecule before atomtyping. If it gives incorrect results or to improve performance disable it with validitychecks=False. Most of these checks can be passed by using the moleculekit.atomtyper.prepareProteinForAtomtyping function. But make sure you understand what you are doing.
#  99%|█████████▉| 287/290 [55:14<00:23,  7.75s/it]2023-08-31 15:16:54,808 - moleculekit.smallmol.smallmol - INFO - Adding any missing hydrogens (fixHs=True)
# 2023-08-31 15:16:54,982 - moleculekit.molecule - INFO - Removed 1841 atoms. 8506 atoms remaining in the molecule.
# 2023-08-31 15:17:14,193 - moleculekit.tools.preparation - WARNING - Dubious protonation state: the pKa of 11 residues is within 1.0 units of pH 7.4.
# 2023-08-31 15:17:14,194 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    ASP    39 A (pKa= 7.30)
# 2023-08-31 15:17:14,195 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU    56 A (pKa= 7.05)
# 2023-08-31 15:17:14,196 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    ASP    39 B (pKa= 7.17)
# 2023-08-31 15:17:14,196 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU    56 B (pKa= 7.14)
# 2023-08-31 15:17:14,197 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS     1 C (pKa= 6.56)
# 2023-08-31 15:17:14,198 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    ASP    39 C (pKa= 7.20)
# 2023-08-31 15:17:14,200 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU    56 C (pKa= 7.30)
# 2023-08-31 15:17:14,201 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    ASP    39 D (pKa= 7.33)
# 2023-08-31 15:17:14,202 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU    56 D (pKa= 7.41)
# 2023-08-31 15:17:14,203 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    ASP    39 E (pKa= 7.10)
# 2023-08-31 15:17:14,204 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU    56 E (pKa= 7.54)
# 2023-08-31 15:17:16,251 - moleculekit.tools.atomtyper - INFO - Checking validity of Molecule before atomtyping. If it gives incorrect results or to improve performance disable it with validitychecks=False. Most of these checks can be passed by using the moleculekit.atomtyper.prepareProteinForAtomtyping function. But make sure you understand what you are doing.
#  99%|█████████▉| 288/290 [55:48<00:31, 15.54s/it]2023-08-31 15:17:28,303 - moleculekit.smallmol.smallmol - INFO - Adding any missing hydrogens (fixHs=True)
# 2023-08-31 15:17:28,321 - moleculekit.molecule - INFO - Removed 314 atoms. 1494 atoms remaining in the molecule.
# 2023-08-31 15:17:30,786 - moleculekit.tools.atomtyper - INFO - Checking validity of Molecule before atomtyping. If it gives incorrect results or to improve performance disable it with validitychecks=False. Most of these checks can be passed by using the moleculekit.atomtyper.prepareProteinForAtomtyping function. But make sure you understand what you are doing.
# 100%|█████████▉| 289/290 [55:52<00:11, 11.99s/it]2023-08-31 15:17:32,072 - moleculekit.smallmol.smallmol - INFO - Adding any missing hydrogens (fixHs=True)
# 2023-08-31 15:17:32,111 - moleculekit.molecule - INFO - Removed 720 atoms. 3404 atoms remaining in the molecule.
# 2023-08-31 15:17:37,576 - moleculekit.tools.preparation - WARNING - Dubious protonation state: the pKa of 4 residues is within 1.0 units of pH 7.4.
# 2023-08-31 15:17:37,578 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU   174 A (pKa= 7.69)
# 2023-08-31 15:17:37,578 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS    65 B (pKa= 6.75)
# 2023-08-31 15:17:37,579 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    HIS   163 B (pKa= 6.61)
# 2023-08-31 15:17:37,580 - moleculekit.tools.preparation - WARNING - Dubious protonation state:    GLU   174 B (pKa= 7.26)
# 2023-08-31 15:17:38,134 - moleculekit.tools.atomtyper - INFO - Checking validity of Molecule before atomtyping. If it gives incorrect results or to improve performance disable it with validitychecks=False. Most of these checks can be passed by using the moleculekit.atomtyper.prepareProteinForAtomtyping function. But make sure you understand what you are doing.
# 100%|██████████| 290/290 [56:01<00:00, 11.59s/it]
# Shapes in the training, test and the validation set:  (288, 24, 24, 24, 16)
# Saving the data in pretest.h5
